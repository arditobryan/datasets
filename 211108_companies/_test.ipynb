# %%
import pandas as pd

pd.read_csv('https://raw.githubusercontent.com/arditoibryan/datasets/main/211108_companies/companies_preprocessed.csv').drop('Unnamed: 0', axis=1)
# Out:
#                            company  \
# 0                        Starbucks
# 1                        Genentech
# 2                        Coca Cola
# 3                              CAT
# 4               Whole Foods Market
# ...                            ...
# 1429            Whole Body Fitness
# 1430  Wingerts Do it Best Hardware
# 1431                  Woods Coffee
# 1432                 Xelle Fitness
# 1433                XSport Fitness
#
#                                                     raw
# 0     Establish Starbucks as the premier purveyor of...
# 1     To develop drugs to address significant unmet ...
# 2     To refresh the worldâ€¦To inspire moments of o...
# 3     To enable economic growth through infrastructu...
# 4     Our deepest purpose as an organization is help...
# ...                                                 ...
# 1429  We will help educate, motivate and support our...
# 1430  Our mission is to make your shopping experienc...
# ...
